# %%
# !pip install psycopg2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import numpy as np
import pandas as pd

# %%
youtube_df_us = pd.read_csv('/content/US_youtube_trending_data.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-5-d5df0069828e> in <module>
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#     104       timeout_ms=timeout_ms,
#     105       ephemeral=True,
# --> 106       readonly=readonly)
#     107
#     108
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     123   if ephemeral:
#     124     _message.blocking_request(
# --> 125         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None)
#     126
#     127   mountpoint = _os.path.expanduser(mountpoint)
#
# ...

# %%
youtube_df_in = pd.read_csv('/content/IN_youtube_trending_data.csv')

# %%
youtube_df_ca = pd.read_csv('/content/CA_youtube_trending_data.csv')

# %% [markdown]
# **Cleanup of US dataset**

# %%
youtube_df_us.head()
# Out:
#       video_id                                              title  \
# 0  3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 1  M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...
# 2  J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 3  kXLn3HkpjaA  XXL 2020 Freshman Class Revealed - Official An...
# 4  VIUo6yapDbc  Ultimate DIY Home Movie Theater for The LaBran...
#
#             publishedAt                 channelId   channelTitle  categoryId  \
# 0  2020-08-11T19:20:14Z  UCvtRTOMP2TqYqu51xNrqAzg       Brawadis          22
# 1  2020-08-11T17:00:10Z  UC0ZV6M2THA81QT9hrVWJG3A   Apex Legends          20
# 2  2020-08-11T16:34:06Z  UCYzPXprvl5Y-Sf0g4vX-m6g  jacksepticeye          24
# 3  2020-08-11T16:38:55Z  UCbg_UMjlHJg_19SZckaKajg            XXL          10
# 4  2020-08-11T15:10:05Z  UCDVPcEbVLQgLZX0Rt6jo34A       Mr. Kate          26
#
#           trending_date                                               tags  \
# ...

# %%
type(youtube_df_us)
# Out:
# pandas.core.frame.DataFrame

# %%
youtube_df_us.shape
# Out:
# (164790, 16)

# %%
youtube_df_us.drop(['channelId','channelTitle','thumbnail_link'],axis=1)
# Out:
#            video_id                                              title  \
# 0       3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 1       M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...
# 2       J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 3       kXLn3HkpjaA  XXL 2020 Freshman Class Revealed - Official An...
# 4       VIUo6yapDbc  Ultimate DIY Home Movie Theater for The LaBran...
# ...             ...                                                ...
# 164785  mZILRPjsaew     A Christmas Story Christmas – Official Trailer
# 164786  jMkRQFqahkQ  Police give update on Migos rapper Takeoff's d...
# 164787  lIJTbTPAADo  Chase Claypool: 'I'm excited to make plays' | ...
# 164788  c9r8JmjK22Y                         Definitely Not Lip Syncing
# 164789  5NjZ-WAmXEE     Why a Huge Chunk Of Earth's History Is Missing
#
#                  publishedAt  categoryId         trending_date  \
# ...

# %%
youtube_df_us.head()
# Out:
#       video_id                                              title  \
# 0  3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 1  M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...
# 2  J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 3  kXLn3HkpjaA  XXL 2020 Freshman Class Revealed - Official An...
# 4  VIUo6yapDbc  Ultimate DIY Home Movie Theater for The LaBran...
#
#             publishedAt                 channelId   channelTitle  categoryId  \
# 0  2020-08-11T19:20:14Z  UCvtRTOMP2TqYqu51xNrqAzg       Brawadis          22
# 1  2020-08-11T17:00:10Z  UC0ZV6M2THA81QT9hrVWJG3A   Apex Legends          20
# 2  2020-08-11T16:34:06Z  UCYzPXprvl5Y-Sf0g4vX-m6g  jacksepticeye          24
# 3  2020-08-11T16:38:55Z  UCbg_UMjlHJg_19SZckaKajg            XXL          10
# 4  2020-08-11T15:10:05Z  UCDVPcEbVLQgLZX0Rt6jo34A       Mr. Kate          26
#
#           trending_date                                               tags  \
# ...

# %%
youtube_df_us.shape
# Out:
# (164790, 16)

# %%
youtube_df_us.isna().sum()
# Out:
# video_id                0
# title                   0
# publishedAt             0
# channelId               0
# channelTitle            0
# categoryId              0
# trending_date           0
# tags                    0
# view_count              0
# likes                   0
# dislikes                0
# comment_count           0
# thumbnail_link          0
# comments_disabled       0
# ratings_disabled        0
# description          3858
# dtype: int64

# %%
youtube_df_us = youtube_df_us.dropna()

# %%
youtube_df_us.isna().sum()
# Out:
# video_id             0
# title                0
# publishedAt          0
# channelId            0
# channelTitle         0
# categoryId           0
# trending_date        0
# tags                 0
# view_count           0
# likes                0
# dislikes             0
# comment_count        0
# thumbnail_link       0
# comments_disabled    0
# ratings_disabled     0
# description          0
# dtype: int64

# %%
youtube_df_us['time_of_day'] = pd.cut(pd.to_datetime(youtube_df_us.publishedAt).dt.hour,
       bins=[0, 6, 12, 18, 24],
       labels=['Night', 'Morning', 'Afternoon', 'Evening'],
       right=False,
       include_lowest=True)

# %%
youtube_df_us['day_of_week'] = pd.DatetimeIndex(youtube_df_us['publishedAt']).day_name()
youtube_df_us.head()
# Out:
#       video_id                                              title  \
# 0  3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 1  M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...
# 2  J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 3  kXLn3HkpjaA  XXL 2020 Freshman Class Revealed - Official An...
# 4  VIUo6yapDbc  Ultimate DIY Home Movie Theater for The LaBran...
#
#             publishedAt                 channelId   channelTitle  categoryId  \
# 0  2020-08-11T19:20:14Z  UCvtRTOMP2TqYqu51xNrqAzg       Brawadis          22
# 1  2020-08-11T17:00:10Z  UC0ZV6M2THA81QT9hrVWJG3A   Apex Legends          20
# 2  2020-08-11T16:34:06Z  UCYzPXprvl5Y-Sf0g4vX-m6g  jacksepticeye          24
# 3  2020-08-11T16:38:55Z  UCbg_UMjlHJg_19SZckaKajg            XXL          10
# 4  2020-08-11T15:10:05Z  UCDVPcEbVLQgLZX0Rt6jo34A       Mr. Kate          26
#
#           trending_date                                               tags  \
# ...

# %%
youtube_df_us['day_of_week'].value_counts()
# Out:
# Friday       26815
# Tuesday      24009
# Monday       23658
# Wednesday    22792
# Sunday       22608
# Thursday     20891
# Saturday     20159
# Name: day_of_week, dtype: int64

# %%
youtube_df_us['time_of_day'].value_counts()
# Out:
# Afternoon    62788
# Evening      55626
# Night        32270
# Morning      10248
# Name: time_of_day, dtype: int64

# %%
youtube_df_us.to_csv("clean_youtube_dataframe_us.csv")

# %% [markdown]
# **Cleanup of IN dataset**

# %%
youtube_df_in.head()
# Out:
#       video_id                                              title  \
# 0  Iot0eF6EoNA  Sadak 2 | Official Trailer | Sanjay | Pooja | ...
# 1  x-KbnJ9fvJc  Kya Baat Aa : Karan Aujla (Official Video) Tan...
# 2  KX06ksuS6Xo  Diljit Dosanjh: CLASH (Official) Music Video |...
# 3  UsMRgnTcchY  Dil Ko Maine Di Kasam Video | Amaal M Ft.Ariji...
# 4  WNSEXJJhKTU  Baarish (Official Video) Payal Dev,Stebin Ben ...
#
#             publishedAt                 channelId    channelTitle  categoryId  \
# 0  2020-08-12T04:31:41Z  UCGqvJPRcv7aVFun-eTsatcA    FoxStarHindi          24
# 1  2020-08-11T09:00:11Z  UCm9SZAl03Rev9sFwloCdz1g  Rehaan Records          10
# 2  2020-08-11T07:30:02Z  UCZRdNleCgW-BGUJf-bbjzQg  Diljit Dosanjh          10
# 3  2020-08-10T05:30:49Z  UCq-Fj5jknLsUf-MWSy4_brA        T-Series          10
# 4  2020-08-11T05:30:13Z  UCye6Oz0mg46S362LwARGVcA   VYRLOriginals          10
#
#           trending_date                                               tags  \
# ...

# %%
youtube_df_in.head(35)
# Out:
#        video_id                                              title  \
# 0   Iot0eF6EoNA  Sadak 2 | Official Trailer | Sanjay | Pooja | ...
# 1   x-KbnJ9fvJc  Kya Baat Aa : Karan Aujla (Official Video) Tan...
# 2   KX06ksuS6Xo  Diljit Dosanjh: CLASH (Official) Music Video |...
# 3   UsMRgnTcchY  Dil Ko Maine Di Kasam Video | Amaal M Ft.Ariji...
# 4   WNSEXJJhKTU  Baarish (Official Video) Payal Dev,Stebin Ben ...
# 5   Xma15IYe5tQ                             SISTER DOES MY HAIRCUT
# 6   uUXE9qUHVzk  Paapi Munda - Mankirt Aulakh Ft. Gur Sidhu | K...
# 7   4dRHHupQM-s            Naagin 5 | नागिन 5 | Episode 01 | Recap
# 8   -h9fY8j22yg                                Ludo | BakLol Video
# 9   XM4Kd1gQ7Ek  Jatti Jaandi (Official Video) | Kambi Ft. Mahi...
# 10  n8vlEklS3gA          Who Is BINOD? How We Created a VIRAL Meme
# 11  ltIe2dFloFY   Medical Shop Alaparaigal | Lockdown | Nakkalites
# 12  KrXRnIESDxM              first Crazy RIDE on Kawasaki NINJA H2
# ...

# %%
type(youtube_df_in)
# Out:
# pandas.core.frame.DataFrame

# %%
youtube_df_in.shape
# Out:
# (149834, 16)

# %%
youtube_df_in.drop(['channelId','channelTitle','thumbnail_link'],axis=1)
# Out:
#            video_id                                              title  \
# 0       Iot0eF6EoNA  Sadak 2 | Official Trailer | Sanjay | Pooja | ...
# 1       x-KbnJ9fvJc  Kya Baat Aa : Karan Aujla (Official Video) Tan...
# 2       KX06ksuS6Xo  Diljit Dosanjh: CLASH (Official) Music Video |...
# 3       UsMRgnTcchY  Dil Ko Maine Di Kasam Video | Amaal M Ft.Ariji...
# 4       WNSEXJJhKTU  Baarish (Official Video) Payal Dev,Stebin Ben ...
# ...             ...                                                ...
# 149829  2XWPvrMU_eI  Naagin 6 | नागिन 6 | Ep. 65 | Anmol Meets Prat...
# 149830  AH9EQG2UUuA  CANDY DISPENSER! 🍬Brings back so much memories...
# 149831  YzEdgEwvmVU  Buying sanitary pads: then vs now #shorts #ree...
# 149832  v0eIgTR8wJg  Indian Idol 13 | Anushka ने किया Himesh जी की ...
# 149833  JlD_ALoujtM      How to Reset the Gut? (Detox Your Intestines)
#
#                  publishedAt  categoryId         trending_date  \
# ...

# %%
youtube_df_in.isna().sum()
# Out:
# video_id                 0
# title                    0
# publishedAt              0
# channelId                0
# channelTitle             1
# categoryId               0
# trending_date            0
# tags                     0
# view_count               0
# likes                    0
# dislikes                 0
# comment_count            0
# thumbnail_link           0
# comments_disabled        0
# ratings_disabled         0
# description          16240
# dtype: int64

# %%
youtube_df_in = youtube_df_in.dropna()

# %%
youtube_df_in.isna().sum()
# Out:
# video_id             0
# title                0
# publishedAt          0
# channelId            0
# channelTitle         0
# categoryId           0
# trending_date        0
# tags                 0
# view_count           0
# likes                0
# dislikes             0
# comment_count        0
# thumbnail_link       0
# comments_disabled    0
# ratings_disabled     0
# description          0
# dtype: int64

# %%
youtube_df_in['time_of_day'] = pd.cut(pd.to_datetime(youtube_df_in.publishedAt).dt.hour,
       bins=[0, 6, 12, 18, 24],
       labels=['Night', 'Morning', 'Afternoon', 'Evening'],
       right=False,
       include_lowest=True)

# %%
youtube_df_in['day_of_week'] = pd.DatetimeIndex(youtube_df_in['publishedAt']).day_name()
youtube_df_in.head()
# Out:
#       video_id                                              title  \
# 0  Iot0eF6EoNA  Sadak 2 | Official Trailer | Sanjay | Pooja | ...
# 1  x-KbnJ9fvJc  Kya Baat Aa : Karan Aujla (Official Video) Tan...
# 2  KX06ksuS6Xo  Diljit Dosanjh: CLASH (Official) Music Video |...
# 3  UsMRgnTcchY  Dil Ko Maine Di Kasam Video | Amaal M Ft.Ariji...
# 4  WNSEXJJhKTU  Baarish (Official Video) Payal Dev,Stebin Ben ...
#
#             publishedAt                 channelId    channelTitle  categoryId  \
# 0  2020-08-12T04:31:41Z  UCGqvJPRcv7aVFun-eTsatcA    FoxStarHindi          24
# 1  2020-08-11T09:00:11Z  UCm9SZAl03Rev9sFwloCdz1g  Rehaan Records          10
# 2  2020-08-11T07:30:02Z  UCZRdNleCgW-BGUJf-bbjzQg  Diljit Dosanjh          10
# 3  2020-08-10T05:30:49Z  UCq-Fj5jknLsUf-MWSy4_brA        T-Series          10
# 4  2020-08-11T05:30:13Z  UCye6Oz0mg46S362LwARGVcA   VYRLOriginals          10
#
#           trending_date                                               tags  \
# ...

# %%
youtube_df_in['day_of_week'].value_counts()
# Out:
# Friday       21129
# Thursday     19587
# Wednesday    19454
# Tuesday      19281
# Saturday     18321
# Monday       18062
# Sunday       17759
# Name: day_of_week, dtype: int64

# %%
youtube_df_in['time_of_day'].value_counts()
# Out:
# Morning      49110
# Afternoon    43187
# Night        36159
# Evening       5137
# Name: time_of_day, dtype: int64

# %%
youtube_df_in.to_csv("clean_youtube_dataframe_in.csv")

# %% [markdown]
# **Cleanup of CA dataset**

# %%
youtube_df_ca.head()
# Out:
#       video_id                                              title  \
# 0  KX06ksuS6Xo  Diljit Dosanjh: CLASH (Official) Music Video |...
# 1  J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 2  M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...
# 3  3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 4  VIUo6yapDbc  Ultimate DIY Home Movie Theater for The LaBran...
#
#             publishedAt                 channelId    channelTitle  categoryId  \
# 0  2020-08-11T07:30:02Z  UCZRdNleCgW-BGUJf-bbjzQg  Diljit Dosanjh          10
# 1  2020-08-11T16:34:06Z  UCYzPXprvl5Y-Sf0g4vX-m6g   jacksepticeye          24
# 2  2020-08-11T17:00:10Z  UC0ZV6M2THA81QT9hrVWJG3A    Apex Legends          20
# 3  2020-08-11T19:20:14Z  UCvtRTOMP2TqYqu51xNrqAzg        Brawadis          22
# 4  2020-08-11T15:10:05Z  UCDVPcEbVLQgLZX0Rt6jo34A        Mr. Kate          26
#
#           trending_date                                               tags  \
# ...

# %%
type(youtube_df_ca)
# Out:
# pandas.core.frame.DataFrame

# %%
youtube_df_ca.shape
# Out:
# (164743, 16)

# %%
youtube_df_ca.drop(['channelId','channelTitle','thumbnail_link'],axis=1)
# Out:
#            video_id                                              title  \
# 0       KX06ksuS6Xo  Diljit Dosanjh: CLASH (Official) Music Video |...
# 1       J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 2       M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...
# 3       3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 4       VIUo6yapDbc  Ultimate DIY Home Movie Theater for The LaBran...
# ...             ...                                                ...
# 164738  UdgRUCVUts0                   The iPhone USB-C Law: Explained!
# 164739  SNh6EFvTw3w  What Bruce Springsteen Thinks of Taylor Swift’...
# 164740  pDUZGyjfB1E                                 xQc kisses NYYXXII
# 164741  1Mct49qAeNM  Nahida CHANGES The META! C0 Nahida 4★ Weapon S...
# 164742  pY628jRd6gM                                    USSF-44 Mission
#
#                  publishedAt  categoryId         trending_date  \
# ...

# %%
youtube_df_ca.isna().sum()
# Out:
# video_id                0
# title                   0
# publishedAt             0
# channelId               0
# channelTitle            0
# categoryId              0
# trending_date           0
# tags                    0
# view_count              0
# likes                   0
# dislikes                0
# comment_count           0
# thumbnail_link          0
# comments_disabled       0
# ratings_disabled        0
# description          3964
# dtype: int64

# %%
youtube_df_ca = youtube_df_ca.dropna()

# %%
youtube_df_ca.isna().sum()
# Out:
# video_id             0
# title                0
# publishedAt          0
# channelId            0
# channelTitle         0
# categoryId           0
# trending_date        0
# tags                 0
# view_count           0
# likes                0
# dislikes             0
# comment_count        0
# thumbnail_link       0
# comments_disabled    0
# ratings_disabled     0
# description          0
# dtype: int64

# %%
youtube_df_ca['time_of_day'] = pd.cut(pd.to_datetime(youtube_df_ca.publishedAt).dt.hour,
       bins=[0, 6, 12, 18, 24],
       labels=['Night', 'Morning', 'Afternoon', 'Evening'],
       right=False,
       include_lowest=True)

# %%
youtube_df_ca['day_of_week'] = pd.DatetimeIndex(youtube_df_ca['publishedAt']).day_name()
youtube_df_ca.head()
# Out:
#       video_id                                              title  \
# 0  KX06ksuS6Xo  Diljit Dosanjh: CLASH (Official) Music Video |...
# 1  J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 2  M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...
# 3  3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 4  VIUo6yapDbc  Ultimate DIY Home Movie Theater for The LaBran...
#
#             publishedAt                 channelId    channelTitle  categoryId  \
# 0  2020-08-11T07:30:02Z  UCZRdNleCgW-BGUJf-bbjzQg  Diljit Dosanjh          10
# 1  2020-08-11T16:34:06Z  UCYzPXprvl5Y-Sf0g4vX-m6g   jacksepticeye          24
# 2  2020-08-11T17:00:10Z  UC0ZV6M2THA81QT9hrVWJG3A    Apex Legends          20
# 3  2020-08-11T19:20:14Z  UCvtRTOMP2TqYqu51xNrqAzg        Brawadis          22
# 4  2020-08-11T15:10:05Z  UCDVPcEbVLQgLZX0Rt6jo34A        Mr. Kate          26
#
#           trending_date                                               tags  \
# ...

# %%
youtube_df_ca['day_of_week'].value_counts()
# Out:
# Sunday       25617
# Tuesday      24055
# Monday       23991
# Friday       23465
# Wednesday    22313
# Saturday     21250
# Thursday     20088
# Name: day_of_week, dtype: int64

# %%
youtube_df_ca['time_of_day'].value_counts()
# Out:
# Afternoon    68945
# Evening      51434
# Night        25455
# Morning      14945
# Name: time_of_day, dtype: int64

# %%
youtube_df_ca.to_csv("clean_youtube_dataframe_ca.csv")
